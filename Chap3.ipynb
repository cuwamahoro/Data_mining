# %%
import numpy as np
import pandas as pd
from matplotlib.pyplot import subplots
import statsmodels.api as sm
from statsmodels.stats.outliers_influence \
import variance_inflation_factor as VIF
from statsmodels.stats.anova import anova_lm
from ISLP import load_data
from ISLP.models import (ModelSpec as MS,
summarize,
poly)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       5 from statsmodels.stats.outliers_influence \
#       6 import variance_inflation_factor as VIF
#       7 from statsmodels.stats.anova import anova_lm
# ----> 8 from ISLP import load_data
#       9 from ISLP.models import (ModelSpec as MS,
#      10 summarize,
#      11 poly)
#
# ModuleNotFoundError: No module named 'ISLP'

# %%
import ISLP
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import ISLP
#
# ModuleNotFoundError: No module named 'ISLP'
